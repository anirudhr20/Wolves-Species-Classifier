# %% [markdown]
# <a href="https://colab.research.google.com/github/anirudhr20/Wolves-Species-Classifier/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive"
base_dir = root_dir + 'fastai-v3'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Auth Code:-4/pAHQ3OQIqLmqyJfAxvutALwibT2rYglNMYGKEiPhcFVSv_2A4TBCh5U

# %%
folder = 'arctus'
file = 'arctus.csv'

# %%
folder = 'dingo'
file = 'dingo.csv'

# %%
folder = 'lupus'
file = 'lupus.csv'

# %%
path = Path(root_dir+'/data/wolves')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/data/wolves/dingo.csv'),
#  PosixPath('/content/gdrive/My Drive/data/wolves/lupus.csv'),
#  PosixPath('/content/gdrive/My Drive/data/wolves/dingo'),
#  PosixPath('/content/gdrive/My Drive/data/wolves/lupus'),
#  PosixPath('/content/gdrive/My Drive/data/wolves/arctus.csv'),
#  PosixPath('/content/gdrive/My Drive/data/wolves/arctus')]

# %%
classes = ['arctus','dingo','lupus']

# %%
download_images(path/file, dest, max_pics=200, max_workers=0)

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

# %%
np.random.seed(42)

data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,bs=64,
          ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['arctus', 'dingo', 'lupus']

# %%
data.show_batch(rows=3,figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['arctus', 'dingo', 'lupus'], 3, 460, 114)

# %%
learn = cnn_learner(data,models.resnet34,metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:01<00:00, 47658867.70it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.882113</td>
#       <td>0.214326</td>
#       <td>0.043860</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.483843</td>
#       <td>0.071628</td>
#       <td>0.035088</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.352263</td>
#       <td>0.058037</td>
#       <td>0.035088</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.272223</td>
#       <td>0.058138</td>
#       <td>0.035088</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2,max_lr=slice(2e-5,2e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.039072</td>
#       <td>0.041355</td>
#       <td>0.026316</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.046219</td>
#       <td>0.036574</td>
#       <td>0.017544</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()
